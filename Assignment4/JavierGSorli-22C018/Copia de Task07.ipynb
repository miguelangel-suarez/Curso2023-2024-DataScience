# %% [markdown]
# **Task 07: Querying RDF(s)**

# %%
# !pip install rdflib
github_storage = "https://raw.githubusercontent.com/FacultadInformatica-LinkedData/Curso2023-2024/master/Assignment4/course_materials"
# Out:
# Collecting rdflib
#   Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 7.1 MB/s eta 0:00:00
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (3.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.6.1 rdflib-7.0.0

# %% [markdown]
# First let's read the RDF file

# %%
from rdflib import Graph, Namespace, Literal
from rdflib.namespace import RDF, RDFS
g = Graph()
g.namespace_manager.bind('ns', Namespace("http://somewhere#"), override=False)
g.namespace_manager.bind('vcard', Namespace("http://www.w3.org/2001/vcard-rdf/3.0#"), override=False)
g.parse(github_storage+"/rdf/example6.rdf", format="xml")
# Out:
# <Graph identifier=Nb1c471fef477447e99162663ce6cd998 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# **TASK 7.1: List all subclasses of "LivingThing" with RDFLib and SPARQL**

# %%
from rdflib.plugins.sparql import prepareQuery

ns=Namespace("http://somewhere#")

q1 = prepareQuery('''
  SELECT ?Subject WHERE{
    # ?Subject rdfs:subClassOf ns:LivingThing.
  }
  ''',
  initNs = {"rdfs" : RDFS, "ns": ns}
)

for r in g.query(q1):
  print(r.Subject)
# Out:
# http://somewhere#Person
# http://somewhere#Animal

# %% [markdown]
# **TASK 7.2: List all individuals of "Person" with RDFLib and SPARQL (remember the subClasses)**

# %%
q1 = prepareQuery('''
  SELECT ?Subject WHERE{
    # ?Subject RDF:type ns:Person.
  }
  ''',
  initNs = {"RDF" : RDF, "ns": ns}
)

for r in g.query(q1):
  print(r.Subject)
# Out:
# http://somewhere#SaraJones
# http://somewhere#JohnSmith

# %% [markdown]
# **TASK 7.3: List all individuals of "Person" or "Animal" and all their properties including their class with RDFLib and SPARQL. You do not need to list the individuals of the subclasses of person**

# %%
q1 = prepareQuery('''
  SELECT ?Subject ?clase ?propiedad ?valor
  WHERE{
    # ?Subject RDF:type ?clase.
    # ?Subject ?propiedad ?valor.
    FILTER (?clase = ns:Animal || ?clase = ns:Person)
  }
  ''',
  initNs = {"RDF" : RDF, "ns": ns}
)

for r in g.query(q1):
  print(r.Subject, r.propiedad, r.clase, r.valor)
# Out:
# http://somewhere#RockySmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Animal http://somewhere#Animal
# http://somewhere#RockySmith http://www.w3.org/2001/vcard-rdf/3.0/Given http://somewhere#Animal Rocky
# http://somewhere#RockySmith http://www.w3.org/2001/vcard-rdf/3.0/FN http://somewhere#Animal Rocky Smith
# http://somewhere#RockySmith http://www.w3.org/2001/vcard-rdf/3.0/Family http://somewhere#Animal Smith
# http://somewhere#RockySmith http://xmlns.com/foaf/0.1/knows http://somewhere#Animal http://somewhere#JaneSmith
# http://somewhere#RockySmith http://xmlns.com/foaf/0.1/knows http://somewhere#Animal http://somewhere#SaraJones
# http://somewhere#SaraJones http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person http://somewhere#Person
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Given http://somewhere#Person Sara
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/FN http://somewhere#Person Sara Jones
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Family http://somewhere#Person Jones
# http://somewhere#SaraJones http://xmlns.com/foaf/0.1/knows http://somewhere#Person http://somewhere#RockySmith
# http://somewhere#SaraJones http://xmlns.com/foaf/0.1/knows http://somewhere#Person http://somewhere#JaneSmith
# http://somewhere#JohnSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person http://somewhere#Person
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Given http://somewhere#Person John
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/FN http://somewhere#Person John Smith
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Family http://somewhere#Person Smith

# %% [markdown]
# **TASK 7.4:  List the name of the persons who know Rocky**

# %%
q1 = prepareQuery('''
  SELECT ?Subject
  WHERE{
    # ?Subject foaf:knows ns:RockySmith.
    # ?Subject RDF:type ns:Person.
  }
  ''',
  initNs = {"RDF" : RDF, "ns": ns}
)

for r in g.query(q1):
  print(r.Subject)
# Out:
# http://somewhere#SaraJones

# %% [markdown]
# **Task 7.5: List the entities who know at least two other entities in the graph**

# %%
# TO DO
# Visualize the results
